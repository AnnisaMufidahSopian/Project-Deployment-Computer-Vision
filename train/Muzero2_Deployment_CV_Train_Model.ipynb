# %% [markdown]
# # Klasifikasi Dataset CIFAR 10 (Model CNN)
#
# **Contoh Deloyment untuk Domain Computer Vision (CV)** <br>
# Orbit Future Academy - AI Mastery - KM Batch 4 <br>
# Tim Deployment dan Tim CV<br>
# 2023 <br>
#
# <img src="https://orbitfutureacademy.id/wp-content/uploads/2023/03/OFA-Logo-01.png" alt="Logo Orbit" width="100" height="30">

# %% [markdown]
# ## Modules dan Packages

# %%
# pastikan versi tensorflow == 2.12.0
# jika tidak sesuai, install versi tensorflow yang sesuai
# !pip show tensorflow
# Out:
# Name: tensorflow
# Version: 2.12.0
# Summary: TensorFlow is an open source machine learning framework for everyone.
# Home-page: https://www.tensorflow.org/
# Author: Google Inc.
# Author-email: packages@tensorflow.org
# License: Apache 2.0
# Location: /usr/local/lib/python3.10/dist-packages
# Requires: absl-py, astunparse, flatbuffers, gast, google-pasta, grpcio, h5py, jax, keras, libclang, numpy, opt-einsum, packaging, protobuf, setuptools, six, tensorboard, tensorflow-estimator, tensorflow-io-gcs-filesystem, termcolor, typing-extensions, wrapt
# Required-by: dopamine-rl

# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
import tensorflow.keras
from tensorflow.keras import backend as K
import tensorflow.keras.utils
import ssl
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Activation, Dropout,LeakyReLU
from sklearn.metrics import confusion_matrix, accuracy_score

# %matplotlib inline
K.clear_session()

# %% [markdown]
# ## Import Data

# %%
ssl._create_default_https_context = ssl._create_unverified_context

# %%
(x_train, y_train), (x_test, y_test) = cifar10.load_data()
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 [==============================] - 2s 0us/step

# %%
NUM_CLASSES = 10
cifar10_classes = ["airplane", "automobile", "bird", "cat", "deer", 
                   "dog", "frog", "horse", "ship", "truck"]

# %% [markdown]
# ## Exploratory Data Analysis (EDA)

# %%
print("Train samples:", x_train.shape, y_train.shape)
print("Test samples:", x_test.shape, y_test.shape)
# Out:
# Train samples: (50000, 32, 32, 3) (50000, 1)
# Test samples: (10000, 32, 32, 3) (10000, 1)

# %%
# Menampilkan Gambar pada Dataset Latih
cols = 8
rows = 2
fig = plt.figure(figsize=(2 * cols - 1, 2.5 * rows - 1))
for i in range(cols):
    for j in range(rows):
        random_index = np.random.randint(0, len(y_train))
        ax = fig.add_subplot(rows, cols, i * rows + j + 1)
        ax.grid('off')
        ax.axis('off')
        ax.imshow(x_train[random_index, :])
        ax.set_title(cifar10_classes[y_train[random_index, 0]])
plt.show()

# %% [markdown]
# ## Menyiapkan Data

# %% [markdown]
# Kita akan melakukan normalisasi data input seperti berikut : $$x_{norm} = \frac{x}{255} - 0.5$$
#
# Kita perlu melakukan konversi label kelas menjadi one-hot encoded vectors. Silahkan gunakan __keras.utils.to_categorical__.

# %%
# Normalisasi Input
x_train2 = (x_train / 255) - 0.5
x_test2  = (x_test / 255) - 0.5

# Mengkonversi Label Class menjadi One-Hot Encoded
y_train2 = tensorflow.keras.utils.to_categorical(y_train, NUM_CLASSES)
y_test2  = tensorflow.keras.utils.to_categorical(y_test, NUM_CLASSES)

# %% [markdown]
# ## Membuat Arsitektur Model CNN

# %%
def make_model():
    model = Sequential()
    model.add(Conv2D(16, (3, 3), input_shape=(32, 32, 3), padding='same'))
    model.add(LeakyReLU(0.1))
    model.add(Conv2D(32, (3, 3), padding='same'))
    model.add(LeakyReLU(0.1))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Dropout(0.25))
    model.add(Conv2D(32, (3, 3), padding='same'))
    model.add(LeakyReLU(0.1))
    model.add(Conv2D(64, (3, 3), padding='same'))
    model.add(LeakyReLU(0.1))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Dropout(0.25))
    model.add(Flatten())
    model.add(Dense(256))
    model.add(LeakyReLU(0.1))
    model.add(Dropout(0.5))
    model.add(Dense(10, activation='softmax'))

    return model

# %%
model = make_model()
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 32, 32, 16)        448
#
#  leaky_re_lu (LeakyReLU)     (None, 32, 32, 16)        0
#
#  conv2d_1 (Conv2D)           (None, 32, 32, 32)        4640
#
#  leaky_re_lu_1 (LeakyReLU)   (None, 32, 32, 32)        0
#
#  max_pooling2d (MaxPooling2D  (None, 16, 16, 32)       0
#  )
#
#  dropout (Dropout)           (None, 16, 16, 32)        0
#
#  conv2d_2 (Conv2D)           (None, 16, 16, 32)        9248
#
#  leaky_re_lu_2 (LeakyReLU)   (None, 16, 16, 32)        0
#
#  conv2d_3 (Conv2D)           (None, 16, 16, 64)        18496
#
#  leaky_re_lu_3 (LeakyReLU)   (None, 16, 16, 64)        0
#
#  max_pooling2d_1 (MaxPooling  (None, 8, 8, 64)         0
#  2D)
#
#  dropout_1 (Dropout)         (None, 8, 8, 64)          0
#
#  flatten (Flatten)           (None, 4096)              0
#
#  dense (Dense)               (None, 256)               1048832
#
#  leaky_re_lu_4 (LeakyReLU)   (None, 256)               0
#
#  dropout_2 (Dropout)         (None, 256)               0
#
#  dense_1 (Dense)             (None, 10)                2570
#
# =================================================================
# Total params: 1,084,234
# Trainable params: 1,084,234
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # Train model

# %%
INIT_LR    = 5e-3  
BATCH_SIZE = 32
EPOCHS     = 50

model = make_model() 

model.compile(
    loss      = 'categorical_crossentropy', 
    optimizer = tensorflow.keras.optimizers.Adamax(learning_rate=INIT_LR), 
    metrics   = ['accuracy'] 
)

# %%
# %%time
model.fit(
    x_train2,
    y_train2,  
    batch_size      = BATCH_SIZE,
    epochs          = EPOCHS,
    validation_data = (x_test2, y_test2),
    shuffle         = True,
    verbose         = 1,
)
# Out:
# Epoch 1/50
# 1563/1563 [==============================] - 24s 6ms/step - loss: 1.3517 - accuracy: 0.5155 - val_loss: 1.0255 - val_accuracy: 0.6340
# Epoch 2/50
# 1563/1563 [==============================] - 9s 6ms/step - loss: 0.9466 - accuracy: 0.6673 - val_loss: 0.8147 - val_accuracy: 0.7185
# Epoch 3/50
# 1563/1563 [==============================] - 10s 6ms/step - loss: 0.8292 - accuracy: 0.7109 - val_loss: 0.7466 - val_accuracy: 0.7377
# Epoch 4/50
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.7559 - accuracy: 0.7365 - val_loss: 0.7482 - val_accuracy: 0.7426
# Epoch 5/50
# 1563/1563 [==============================] - 9s 6ms/step - loss: 0.7028 - accuracy: 0.7555 - val_loss: 0.6931 - val_accuracy: 0.7600
# Epoch 6/50
# 1563/1563 [==============================] - 10s 6ms/step - loss: 0.6680 - accuracy: 0.7671 - val_loss: 0.6612 - val_accuracy: 0.7754
# Epoch 7/50
# 1563/1563 [==============================] - 9s 6ms/step - loss: 0.6339 - accuracy: 0.7779 - val_loss: 0.6751 - val_accuracy: 0.7743
# Epoch 8/50
# 1563/1563 [==============================] - 9s 6ms/step - loss: 0.6132 - accuracy: 0.7832 - val_loss: 0.6799 - val_accuracy: 0.7704
# Epoch 9/50
# 1563/1563 [==============================] - 10s 6ms/step - loss: 0.5869 - accuracy: 0.7928 - val_loss: 0.6658 - val_accuracy: 0.7787
# Epoch 10/50
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.5706 - accuracy: 0.8009 - val_loss: 0.6700 - val_accuracy: 0.7811
# Epoch 11/50
# 1563/1563 [==============================] - 9s 6ms/step - loss: 0.5567 - accuracy: 0.8057 - val_loss: 0.6585 - val_accuracy: 0.7777
# Epoch 12/50
# 1563/1563 [==============================] - 9s 6ms/step - loss: 0.5392 - accuracy: 0.8108 - val_loss: 0.6282 - val_accuracy: 0.7907
# Epoch 13/50
# 1563/1563 [==============================] - 9s 6ms/step - loss: 0.5207 - accuracy: 0.8174 - val_loss: 0.6528 - val_accuracy: 0.7984
# Epoch 14/50
# 1563/1563 [==============================] - 9s 6ms/step - loss: 0.5095 - accuracy: 0.8218 - val_loss: 0.6325 - val_accuracy: 0.7982
# Epoch 15/50
# 1563/1563 [==============================] - 10s 6ms/step - loss: 0.4979 - accuracy: 0.8251 - val_loss: 0.6505 - val_accuracy: 0.7917
# Epoch 16/50
# 1563/1563 [==============================] - 9s 6ms/step - loss: 0.4856 - accuracy: 0.8312 - val_loss: 0.6457 - val_accuracy: 0.7945
# Epoch 17/50
# 1563/1563 [==============================] - 9s 6ms/step - loss: 0.4742 - accuracy: 0.8336 - val_loss: 0.6552 - val_accuracy: 0.7947
# Epoch 18/50
# 1563/1563 [==============================] - 9s 6ms/step - loss: 0.4719 - accuracy: 0.8363 - val_loss: 0.6069 - val_accuracy: 0.7983
# Epoch 19/50
# 1563/1563 [==============================] - 9s 6ms/step - loss: 0.4620 - accuracy: 0.8384 - val_loss: 0.6559 - val_accuracy: 0.7909
# Epoch 20/50
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.4574 - accuracy: 0.8412 - val_loss: 0.7115 - val_accuracy: 0.8014
# Epoch 21/50
# 1563/1563 [==============================] - 9s 6ms/step - loss: 0.4505 - accuracy: 0.8433 - val_loss: 0.6468 - val_accuracy: 0.8039
# Epoch 22/50
# 1563/1563 [==============================] - 9s 6ms/step - loss: 0.4510 - accuracy: 0.8410 - val_loss: 0.6740 - val_accuracy: 0.7920
# Epoch 23/50
# 1563/1563 [==============================] - 9s 6ms/step - loss: 0.4356 - accuracy: 0.8496 - val_loss: 0.6711 - val_accuracy: 0.7900
# Epoch 24/50
# 1563/1563 [==============================] - 9s 6ms/step - loss: 0.4279 - accuracy: 0.8501 - val_loss: 0.6547 - val_accuracy: 0.7964
# Epoch 25/50
# 1563/1563 [==============================] - 9s 6ms/step - loss: 0.4250 - accuracy: 0.8510 - val_loss: 0.6514 - val_accuracy: 0.8083
# Epoch 26/50
# 1563/1563 [==============================] - 9s 6ms/step - loss: 0.4211 - accuracy: 0.8527 - val_loss: 0.6212 - val_accuracy: 0.8104
# Epoch 27/50
# 1563/1563 [==============================] - 9s 6ms/step - loss: 0.4111 - accuracy: 0.8551 - val_loss: 0.6430 - val_accuracy: 0.7997
# Epoch 28/50
# 1563/1563 [==============================] - 9s 6ms/step - loss: 0.4101 - accuracy: 0.8569 - val_loss: 0.6578 - val_accuracy: 0.8053
# Epoch 29/50
# 1563/1563 [==============================] - 9s 6ms/step - loss: 0.4075 - accuracy: 0.8596 - val_loss: 0.6503 - val_accuracy: 0.8002
# Epoch 30/50
# 1563/1563 [==============================] - 9s 6ms/step - loss: 0.4064 - accuracy: 0.8584 - val_loss: 0.7265 - val_accuracy: 0.7980
# Epoch 31/50
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.4092 - accuracy: 0.8583 - val_loss: 0.5981 - val_accuracy: 0.8024
# Epoch 32/50
# 1563/1563 [==============================] - 9s 6ms/step - loss: 0.3988 - accuracy: 0.8614 - val_loss: 0.6051 - val_accuracy: 0.8027
# Epoch 33/50
# 1563/1563 [==============================] - 9s 6ms/step - loss: 0.3973 - accuracy: 0.8649 - val_loss: 0.7077 - val_accuracy: 0.8080
# Epoch 34/50
# 1563/1563 [==============================] - 9s 6ms/step - loss: 0.3910 - accuracy: 0.8637 - val_loss: 0.6320 - val_accuracy: 0.8055
# Epoch 35/50
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.3862 - accuracy: 0.8663 - val_loss: 0.6437 - val_accuracy: 0.8103
# Epoch 36/50
# 1563/1563 [==============================] - 9s 6ms/step - loss: 0.3854 - accuracy: 0.8656 - val_loss: 0.6467 - val_accuracy: 0.8031
# Epoch 37/50
# 1563/1563 [==============================] - 10s 6ms/step - loss: 0.3890 - accuracy: 0.8658 - val_loss: 0.6535 - val_accuracy: 0.8093
# Epoch 38/50
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.3801 - accuracy: 0.8684 - val_loss: 0.6800 - val_accuracy: 0.8016
# Epoch 39/50
# 1563/1563 [==============================] - 9s 6ms/step - loss: 0.3678 - accuracy: 0.8723 - val_loss: 0.6986 - val_accuracy: 0.8080
# Epoch 40/50
# 1563/1563 [==============================] - 9s 6ms/step - loss: 0.3731 - accuracy: 0.8718 - val_loss: 0.6244 - val_accuracy: 0.8076
# Epoch 41/50
# 1563/1563 [==============================] - 9s 6ms/step - loss: 0.3663 - accuracy: 0.8722 - val_loss: 0.6987 - val_accuracy: 0.8131
# Epoch 42/50
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.3615 - accuracy: 0.8749 - val_loss: 0.6656 - val_accuracy: 0.8077
# Epoch 43/50
# 1563/1563 [==============================] - 9s 6ms/step - loss: 0.3660 - accuracy: 0.8726 - val_loss: 0.7328 - val_accuracy: 0.8071
# Epoch 44/50
# 1563/1563 [==============================] - 9s 6ms/step - loss: 0.3659 - accuracy: 0.8736 - val_loss: 0.6964 - val_accuracy: 0.8079
# Epoch 45/50
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.3620 - accuracy: 0.8757 - val_loss: 0.6880 - val_accuracy: 0.8099
# Epoch 46/50
# 1563/1563 [==============================] - 9s 6ms/step - loss: 0.3602 - accuracy: 0.8760 - val_loss: 0.6285 - val_accuracy: 0.8071
# Epoch 47/50
# 1563/1563 [==============================] - 9s 6ms/step - loss: 0.3521 - accuracy: 0.8785 - val_loss: 0.6603 - val_accuracy: 0.8107
# Epoch 48/50
# 1563/1563 [==============================] - 9s 6ms/step - loss: 0.3501 - accuracy: 0.8792 - val_loss: 0.7813 - val_accuracy: 0.7988
# Epoch 49/50
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.3588 - accuracy: 0.8764 - val_loss: 0.6155 - val_accuracy: 0.8041
# Epoch 50/50
# 1563/1563 [==============================] - 9s 6ms/step - loss: 0.3560 - accuracy: 0.8776 - val_loss: 0.6933 - val_accuracy: 0.8074
# CPU times: user 7min 51s, sys: 39.3 s, total: 8min 30s
# Wall time: 7min 48s

# %% [markdown]
# ## Prediksi

# %%
# Prediksi untuk Data Latih
y_pred_train            = model.predict(x_train2)
y_pred_train_classes    = np.argmax(y_pred_train, axis=1)
y_pred_train_max_probas = np.max(y_pred_train, axis=1)
# Out:
# 1563/1563 [==============================] - 4s 2ms/step

# %%
# Prediksi untuk Data Uji
y_pred_test            = model.predict(x_test2)
y_pred_test_classes    = np.argmax(y_pred_test, axis=1)
y_pred_test_max_probas = np.max(y_pred_test, axis=1)
# Out:
# 313/313 [==============================] - 1s 2ms/step

# %%
# Menampilkan Hasil Prediksi untuk Data Latih
cols = 8
rows = 2
fig = plt.figure(figsize=(2 * cols - 1, 3 * rows - 1))
for i in range(cols):
    for j in range(rows):
        random_index = np.random.randint(0, len(y_train))
        ax = fig.add_subplot(rows, cols, i * rows + j + 1)
        ax.grid('off')
        ax.axis('off')
        ax.imshow(x_train[random_index, :])
        pred_label = cifar10_classes[y_pred_train_classes[random_index]]
        pred_proba = y_pred_train_max_probas[random_index]
        true_label = cifar10_classes[y_train[random_index, 0]]
        ax.set_title("pred: {}\nscore: {:.3}\ntrue: {}".format(
               pred_label, pred_proba, true_label
        ))
plt.show()

# %%
# Menampilkan Hasil Prediksi untuk Data Uji
cols = 8
rows = 2
fig = plt.figure(figsize=(2 * cols - 1, 3 * rows - 1))
for i in range(cols):
    for j in range(rows):
        random_index = np.random.randint(0, len(y_test))
        ax = fig.add_subplot(rows, cols, i * rows + j + 1)
        ax.grid('off')
        ax.axis('off')
        ax.imshow(x_test[random_index, :])
        pred_label = cifar10_classes[y_pred_test_classes[random_index]]
        pred_proba = y_pred_test_max_probas[random_index]
        true_label = cifar10_classes[y_test[random_index, 0]]
        ax.set_title("pred: {}\nscore: {:.3}\ntrue: {}".format(
               pred_label, pred_proba, true_label
        ))
plt.show()

# %% [markdown]
# ## Evaluate model

# %%
# Confusion Matrix dan Akurasi untuk Data Latih
plt.figure(figsize=(7, 6))
plt.title('Confusion Matrix', fontsize=16)
plt.imshow(confusion_matrix(y_train, y_pred_train_classes))
plt.xticks(np.arange(10), cifar10_classes, rotation=45, fontsize=12)
plt.yticks(np.arange(10), cifar10_classes, fontsize=12)
plt.colorbar()
plt.show()

print("Train Accuracy:", accuracy_score(y_train, y_pred_train_classes))
# Out:
# Train Accuracy: 0.97232

# %%
# Confusion Matrix dan Akurasi untuk Data Uji
plt.figure(figsize=(7, 6))
plt.title('Confusion Matrix', fontsize=16)
plt.imshow(confusion_matrix(y_test, y_pred_test_classes))
plt.xticks(np.arange(10), cifar10_classes, rotation=45, fontsize=12)
plt.yticks(np.arange(10), cifar10_classes, fontsize=12)
plt.colorbar()
plt.show()

print("Test Accuracy:", accuracy_score(y_test, y_pred_test_classes))
# Out:
# Test Accuracy: 0.8074

# %% [markdown]
# ## Menyimpan Model

# %%
model.save_weights("model_cifar10_cnn_tf.h5")
